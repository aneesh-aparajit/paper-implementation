# %%
import tensorflow as tf
from tensorflow.keras.layers import (
  Activation, 
  Add, 
  BatchNormalization, 
  Conv2D
)
import typing

# %% [markdown]
# ![Screenshot 2022-06-03 at 10.31.29 PM.png](attachment:3273762a-ac3e-4db3-b94e-e0d337ffdc35.png)

# %% [markdown]
# ![Screenshot 2022-06-03 at 10.31.45 PM.png](attachment:5f68752e-0e90-4823-b396-9907afec2243.png)

# %%
@tf.function
def residual_block(
  X: tf.Tensor, 
  kernel_size: int, 
  num_filters: typing.List[int], 
  block_name: str, 
  downsample: bool, 
  stride: int = 2
):
  """
  """
  if downsample:
    downsample_layer = Conv2D(
      filters=
    )
