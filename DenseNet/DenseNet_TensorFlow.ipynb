# %% [markdown]
# ## Densely Connected Convolutional Networks
# Paper Link: https://arxiv.org/pdf/1608.06993.pdf
#
# ![Screenshot%202022-06-24%20at%204.09.46%20PM.png](attachment:Screenshot%202022-06-24%20at%204.09.46%20PM.png)
